# %% [markdown]
# ### Mount of Drive Folder and Clone/Pull Git Repository

# %%
from google.colab import drive
import os

drive.mount('/content/drive')
repo_path = "/content/sapienza_fds_fruit_classification"

if not os.path.exists(repo_path):
    print("Cloning repository...")
    # !git clone https://github.com/julpfi/sapienza_fds_fruit_classification_hyperspectrial.git {repo_path}
else:
    print("Repository exists. Pulling latest changes...")
    # %cd {repo_path}
    # !git pull origin main

# %cd {repo_path}
# Out:
# Mounted at /content/drive
# Cloning repository...
# Cloning into '/content/sapienza_fds_fruit_classification'...
# remote: Enumerating objects: 909, done.
# remote: Counting objects: 100% (88/88), done.
# remote: Compressing objects: 100% (58/58), done.
# remote: Total 909 (delta 58), reused 57 (delta 30), pack-reused 821 (from 1)
# Receiving objects: 100% (909/909), 100.06 KiB | 9.10 MiB/s, done.
# Resolving deltas: 100% (637/637), done.
# /content/sapienza_fds_fruit_classification

# %% [markdown]
# ### Check if GPU(T4) is Selected

# %%
import torch

# We need to manually select the GPU: Edit -> Notebook settings -> GPU(T4)
if torch.cuda.is_available():
    device_name = torch.cuda.get_device_name(0)
    print(f"SUCCESS: GPU Detected: {device_name}")
else:
    print("WARNING: No GPU detected.")
# Out:
# SUCCESS: GPU Detected: Tesla T4

# %% [markdown]
# ### Setup of Environment in Google Colab

# %%
# !bash scripts/setup_colab.sh
# Out:
# Installing Libraries & Project...
# Obtaining file:///content/sapienza_fds_fruit_classification (from -r requirements.txt (line 11))
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 1)) (2.0.2)
# Requirement already satisfied: pandas in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 2)) (2.2.2)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 3)) (1.6.1)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 4)) (3.10.0)
# Collecting spectral>=0.22 (from -r requirements.txt (line 5))
#   Downloading spectral-0.24-py3-none-any.whl.metadata (1.3 kB)
# Requirement already satisfied: h5py in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 6)) (3.15.1)
# Requirement already satisfied: timm in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 7)) (1.0.22)
# Requirement already satisfied: einops in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 8)) (0.8.1)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 9)) (4.67.1)
# Requirement already satisfied: wandb in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 10)) (0.23.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas->-r requirements.txt (line 2)) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas->-r requirements.txt (line 2)) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas->-r requirements.txt (line 2)) (2025.3)
# Requirement already satisfied: scipy>=1.6.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn->-r requirements.txt (line 3)) (1.16.3)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn->-r requirements.txt (line 3)) (1.5.3)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn->-r requirements.txt (line 3)) (3.6.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->-r requirements.txt (line 4)) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib->-r requirements.txt (line 4)) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib->-r requirements.txt (line 4)) (4.61.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->-r requirements.txt (line 4)) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib->-r requirements.txt (line 4)) (25.0)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.12/dist-packages (from matplotlib->-r requirements.txt (line 4)) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->-r requirements.txt (line 4)) (3.2.5)
# Requirement already satisfied: torch in /usr/local/lib/python3.12/dist-packages (from timm->-r requirements.txt (line 7)) (2.9.0+cu126)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.12/dist-packages (from timm->-r requirements.txt (line 7)) (0.24.0+cu126)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.12/dist-packages (from timm->-r requirements.txt (line 7)) (6.0.3)
# Requirement already satisfied: huggingface_hub in /usr/local/lib/python3.12/dist-packages (from timm->-r requirements.txt (line 7)) (0.36.0)
# Requirement already satisfied: safetensors in /usr/local/lib/python3.12/dist-packages (from timm->-r requirements.txt (line 7)) (0.7.0)
# Requirement already satisfied: click>=8.0.1 in /usr/local/lib/python3.12/dist-packages (from wandb->-r requirements.txt (line 10)) (8.3.1)
# Requirement already satisfied: gitpython!=3.1.29,>=1.0.0 in /usr/local/lib/python3.12/dist-packages (from wandb->-r requirements.txt (line 10)) (3.1.45)
# Requirement already satisfied: platformdirs in /usr/local/lib/python3.12/dist-packages (from wandb->-r requirements.txt (line 10)) (4.5.1)
# Requirement already satisfied: protobuf!=4.21.0,!=5.28.0,<7,>=3.19.0 in /usr/local/lib/python3.12/dist-packages (from wandb->-r requirements.txt (line 10)) (5.29.5)
# Requirement already satisfied: pydantic<3 in /usr/local/lib/python3.12/dist-packages (from wandb->-r requirements.txt (line 10)) (2.12.3)
# Requirement already satisfied: requests<3,>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from wandb->-r requirements.txt (line 10)) (2.32.4)
# Requirement already satisfied: sentry-sdk>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from wandb->-r requirements.txt (line 10)) (2.47.0)
# Requirement already satisfied: typing-extensions<5,>=4.8 in /usr/local/lib/python3.12/dist-packages (from wandb->-r requirements.txt (line 10)) (4.15.0)
# Requirement already satisfied: gitdb<5,>=4.0.1 in /usr/local/lib/python3.12/dist-packages (from gitpython!=3.1.29,>=1.0.0->wandb->-r requirements.txt (line 10)) (4.0.12)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.12/dist-packages (from pydantic<3->wandb->-r requirements.txt (line 10)) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.4 in /usr/local/lib/python3.12/dist-packages (from pydantic<3->wandb->-r requirements.txt (line 10)) (2.41.4)
# Requirement already satisfied: typing-inspection>=0.4.2 in /usr/local/lib/python3.12/dist-packages (from pydantic<3->wandb->-r requirements.txt (line 10)) (0.4.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.8.2->pandas->-r requirements.txt (line 2)) (1.17.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests<3,>=2.0.0->wandb->-r requirements.txt (line 10)) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests<3,>=2.0.0->wandb->-r requirements.txt (line 10)) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests<3,>=2.0.0->wandb->-r requirements.txt (line 10)) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests<3,>=2.0.0->wandb->-r requirements.txt (line 10)) (2025.11.12)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from huggingface_hub->timm->-r requirements.txt (line 7)) (3.20.0)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.12/dist-packages (from huggingface_hub->timm->-r requirements.txt (line 7)) (2025.3.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /usr/local/lib/python3.12/dist-packages (from huggingface_hub->timm->-r requirements.txt (line 7)) (1.2.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from torch->timm->-r requirements.txt (line 7)) (75.2.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch->timm->-r requirements.txt (line 7)) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in /usr/local/lib/python3.12/dist-packages (from torch->timm->-r requirements.txt (line 7)) (3.6.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch->timm->-r requirements.txt (line 7)) (3.1.6)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch->timm->-r requirements.txt (line 7)) (12.6.77)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch->timm->-r requirements.txt (line 7)) (12.6.77)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.6.80 in /usr/local/lib/python3.12/dist-packages (from torch->timm->-r requirements.txt (line 7)) (12.6.80)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in /usr/local/lib/python3.12/dist-packages (from torch->timm->-r requirements.txt (line 7)) (9.10.2.21)
# Requirement already satisfied: nvidia-cublas-cu12==12.6.4.1 in /usr/local/lib/python3.12/dist-packages (from torch->timm->-r requirements.txt (line 7)) (12.6.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.0.4 in /usr/local/lib/python3.12/dist-packages (from torch->timm->-r requirements.txt (line 7)) (11.3.0.4)
# Requirement already satisfied: nvidia-curand-cu12==10.3.7.77 in /usr/local/lib/python3.12/dist-packages (from torch->timm->-r requirements.txt (line 7)) (10.3.7.77)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.1.2 in /usr/local/lib/python3.12/dist-packages (from torch->timm->-r requirements.txt (line 7)) (11.7.1.2)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.4.2 in /usr/local/lib/python3.12/dist-packages (from torch->timm->-r requirements.txt (line 7)) (12.5.4.2)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /usr/local/lib/python3.12/dist-packages (from torch->timm->-r requirements.txt (line 7)) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.27.5 in /usr/local/lib/python3.12/dist-packages (from torch->timm->-r requirements.txt (line 7)) (2.27.5)
# Requirement already satisfied: nvidia-nvshmem-cu12==3.3.20 in /usr/local/lib/python3.12/dist-packages (from torch->timm->-r requirements.txt (line 7)) (3.3.20)
# Requirement already satisfied: nvidia-nvtx-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch->timm->-r requirements.txt (line 7)) (12.6.77)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.6.85 in /usr/local/lib/python3.12/dist-packages (from torch->timm->-r requirements.txt (line 7)) (12.6.85)
# Requirement already satisfied: nvidia-cufile-cu12==1.11.1.6 in /usr/local/lib/python3.12/dist-packages (from torch->timm->-r requirements.txt (line 7)) (1.11.1.6)
# Requirement already satisfied: triton==3.5.0 in /usr/local/lib/python3.12/dist-packages (from torch->timm->-r requirements.txt (line 7)) (3.5.0)
# Requirement already satisfied: smmap<6,>=3.0.1 in /usr/local/lib/python3.12/dist-packages (from gitdb<5,>=4.0.1->gitpython!=3.1.29,>=1.0.0->wandb->-r requirements.txt (line 10)) (5.0.2)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch->timm->-r requirements.txt (line 7)) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch->timm->-r requirements.txt (line 7)) (3.0.3)
# Downloading spectral-0.24-py3-none-any.whl (249 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 249.0/249.0 kB 9.8 MB/s eta 0:00:00
# Installing collected packages: sapienza_fds_fruit_classifier, spectral
#   Running setup.py develop for sapienza_fds_fruit_classifier
# Successfully installed sapienza_fds_fruit_classifier-0.1 spectral-0.24
# Checking Data Connection...
# SUCCESS: Data folder found on Google Drive.
# Setup complete!

# %% [markdown]
# ### Login to Weights and Biases for Logging

# %%
import wandb
from google.colab import userdata

wandb.login(key=userdata.get('WANDB_API_KEY'))
# Out:
# /usr/local/lib/python3.12/dist-packages/notebook/notebookapp.py:191: SyntaxWarning: invalid escape sequence '\/'
#   | |_| | '_ \/ _` / _` |  _/ -_)
# wandb: WARNING If you're specifying your api key in code, ensure this code is not shared publicly.
# wandb: WARNING Consider setting the WANDB_API_KEY environment variable, or running `wandb login` from the command line.
# wandb: No netrc file found, creating one.
# wandb: Appending key for api.wandb.ai to your netrc file: /root/.netrc
# wandb: Currently logged in as: julius-pfingsten (julius-pfingsten-sapienza-universit-di-roma) to https://api.wandb.ai. Use `wandb login --relogin` to force relogin
# True

# %% [markdown]
# ### Execute the Training

# %%
# %cd /content/sapienza_fds_fruit_classification

# Like:
# !python src/train.py
# Out:
# /content/sapienza_fds_fruit_classification
# wandb: Currently logged in as: julius-pfingsten (julius-pfingsten-sapienza-universit-di-roma) to https://api.wandb.ai. Use `wandb login --relogin` to force relogin
# wandb: ⢿ Waiting for wandb.init()...
# wandb: ⣻ Waiting for wandb.init()...
# wandb: ⣽ Waiting for wandb.init()...
# wandb: Tracking run with wandb version 0.23.1
# wandb: Run data is saved locally in /content/sapienza_fds_fruit_classification/wandb/run-20251223_134406-d5yn2sz8
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run avocado_all_bands_deit
# wandb: ⭐️ View project at https://wandb.ai/julius-pfingsten-sapienza-universit-di-roma/sapienza_fds_fruit_ripeness
# wandb: 🚀 View run at https://wandb.ai/julius-pfingsten-sapienza-universit-di-roma/sapienza_fds_fruit_ripeness/runs/d5yn2sz8
# Training on cuda
# Configuration:: {'project_name': 'sapienza_fds_fruit_ripeness', 'run_name': 'avocado_all_bands_deit', 'fruit': <FruitType.KIWI: 'Kiwi'>, 'camera': <CameraType.FX10: 'VIS'>, 'num_classes': 3, 'model_type': 'deit', 'bands': 224, 'band_selection': None, 'band_reduction': 'all', 'img_size': (224, 224), 'batch_size': 16, 'epochs': 25, 'lr': 0.0001, 'num_workers': 2, 'data_root': '/content/drive/MyDrive/sapienza_fds_fruit_classification/data', 'json_root': '/content/drive/MyDrive/sapienza_fds_fruit_classification/data/dataset', 'save_dir': '/content/drive/MyDrive/sapienza_fds_fruit_classification/checkpoints'}
# Loading TRAIN data from: train_kiwi_grouped.json
# Loaded 130 samples for Kiwi
# BandSelector Initialized: No bounds specified. Keeping all bands.
# BadnReducer Initialized: Applying strategy all gettings 224 bands
#
# Loading VAL data from: val_kiwi_grouped.json
# Loaded 28 samples for Kiwi
# BandSelector Initialized: No bounds specified. Keeping all bands.
# BadnReducer Initialized: Applying strategy all gettings 224 bands
#
# Loading TEST data from: test_kiwi_grouped.json
# Loaded 28 samples for Kiwi
# BandSelector Initialized: No bounds specified. Keeping all bands.
# BadnReducer Initialized: Applying strategy all gettings 224 bands
#
# model.safetensors: 100% 23.7M/23.7M [00:03<00:00, 6.77MB/s]
#
# Epoch 1/25
# Training: 100% 9/9 [03:46<00:00, 25.18s/it, loss=2.0244]
# Results: Train Acc: 44.62% | Val Acc: 28.57%
#
# Epoch 2/25
# Training: 100% 9/9 [01:36<00:00, 10.71s/it, loss=1.2079]
# Results: Train Acc: 29.23% | Val Acc: 42.86%
#
# Epoch 3/25
# Training: 100% 9/9 [01:43<00:00, 11.53s/it, loss=1.1963]
# Results: Train Acc: 43.08% | Val Acc: 32.14%
#
# Epoch 4/25
# Training: 100% 9/9 [01:46<00:00, 11.85s/it, loss=1.1657]
# Results: Train Acc: 36.15% | Val Acc: 42.86%
#
# Epoch 5/25
# Training: 100% 9/9 [01:47<00:00, 11.98s/it, loss=1.2668]
# Results: Train Acc: 43.08% | Val Acc: 28.57%
#
# Epoch 6/25
# Training: 100% 9/9 [01:38<00:00, 10.92s/it, loss=0.9320]
# Results: Train Acc: 31.54% | Val Acc: 42.86%
#
# Epoch 7/25
# Training: 100% 9/9 [01:38<00:00, 10.93s/it, loss=1.0951]
# Results: Train Acc: 43.08% | Val Acc: 42.86%
#
# Epoch 8/25
# Training: 100% 9/9 [01:47<00:00, 11.92s/it, loss=1.2594]
# Results: Train Acc: 40.00% | Val Acc: 39.29%
#
# Epoch 9/25
# Training: 100% 9/9 [01:49<00:00, 12.17s/it, loss=0.9768]
# Results: Train Acc: 33.08% | Val Acc: 42.86%
#
# Epoch 10/25
# Training: 100% 9/9 [01:53<00:00, 12.67s/it, loss=1.1937]
# Results: Train Acc: 43.08% | Val Acc: 28.57%
#
# Epoch 11/25
# Training: 100% 9/9 [01:40<00:00, 11.14s/it, loss=1.1201]
# Results: Train Acc: 34.62% | Val Acc: 42.86%
#
# Epoch 12/25
# Training: 100% 9/9 [01:59<00:00, 13.33s/it, loss=1.3193]
# Results: Train Acc: 43.08% | Val Acc: 42.86%
#
# Epoch 13/25
# Training: 100% 9/9 [01:52<00:00, 12.47s/it, loss=1.0038]
# Results: Train Acc: 32.31% | Val Acc: 42.86%
#
# Epoch 14/25
# Training: 100% 9/9 [01:51<00:00, 12.42s/it, loss=0.7911]
# Results: Train Acc: 43.08% | Val Acc: 42.86%
#
# Epoch 15/25
# Training: 100% 9/9 [01:42<00:00, 11.39s/it, loss=0.9764]
# Results: Train Acc: 42.31% | Val Acc: 32.14%
#
# Epoch 16/25
# Training: 100% 9/9 [01:43<00:00, 11.52s/it, loss=1.2949]
# Results: Train Acc: 44.62% | Val Acc: 42.86%
#
# Epoch 17/25
# Training: 100% 9/9 [01:52<00:00, 12.49s/it, loss=1.0408]
# Results: Train Acc: 33.85% | Val Acc: 42.86%
#
# Epoch 18/25
# Training: 100% 9/9 [01:51<00:00, 12.36s/it, loss=1.0167]
# Results: Train Acc: 43.08% | Val Acc: 42.86%
#
# Epoch 19/25
# Training: 100% 9/9 [01:45<00:00, 11.68s/it, loss=0.9530]
# Results: Train Acc: 43.08% | Val Acc: 35.71%
#
# Epoch 20/25
# Training: 100% 9/9 [01:46<00:00, 11.88s/it, loss=1.0705]
# Results: Train Acc: 43.08% | Val Acc: 42.86%
#
# Epoch 21/25
# Training: 100% 9/9 [01:52<00:00, 12.45s/it, loss=0.8629]
# Results: Train Acc: 43.08% | Val Acc: 42.86%
#
# Epoch 22/25
# Training: 100% 9/9 [01:51<00:00, 12.34s/it, loss=1.0729]
# Results: Train Acc: 43.08% | Val Acc: 42.86%
#
# Epoch 23/25
# Training:  56% 5/9 [01:14<00:56, 14.17s/it, loss=1.0348]
